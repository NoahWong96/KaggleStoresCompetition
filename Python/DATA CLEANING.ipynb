# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Data Cleaning

# %%
train = pd.read_csv("../../../Data/train.csv", index_col = 0, parse_dates = ['date'])
test = pd.read_csv("../../../Data/test.csv", index_col = 0)
train.head(20)
# Out:
#          date  store_nbr               family  sales  onpromotion
# id
# 0  2013-01-01          1           AUTOMOTIVE    0.0            0
# 1  2013-01-01          1            BABY CARE    0.0            0
# 2  2013-01-01          1               BEAUTY    0.0            0
# 3  2013-01-01          1            BEVERAGES    0.0            0
# 4  2013-01-01          1                BOOKS    0.0            0
# 5  2013-01-01          1         BREAD/BAKERY    0.0            0
# 6  2013-01-01          1          CELEBRATION    0.0            0
# 7  2013-01-01          1             CLEANING    0.0            0
# 8  2013-01-01          1                DAIRY    0.0            0
# 9  2013-01-01          1                 DELI    0.0            0
# 10 2013-01-01          1                 EGGS    0.0            0
# 11 2013-01-01          1         FROZEN FOODS    0.0            0
# 12 2013-01-01          1            GROCERY I    0.0            0
# ...

# %%
train.shape
trainClean = train.dropna()
trainClean["date"] = pd.to_datetime(trainClean["date"])
trainClean["day_of_week"]= trainClean["date"].dt.day_name()
trainClean["weekend"] = trainClean["day_of_week"].isin(["Saturday", "Sunday"])

# %% [markdown]
# Appending Oil prices to trainClean

# %%
oil = pd.read_csv("../../../Data/oil.csv", names = ["date", "price"],parse_dates = ['date'])
oil = oil.drop(index=0)
oil = oil.dropna()
oil["date"] = pd.to_datetime(oil["date"])
trainClean = trainClean.merge(oil, on="date")
print(trainClean.head())
# Out:
#         date  store_nbr      family   sales  onpromotion day_of_week  weekend  \
# 0 2013-01-02          1  AUTOMOTIVE     2.0            0   Wednesday    False
# 1 2013-01-02          1   BABY CARE     0.0            0   Wednesday    False
# 2 2013-01-02          1      BEAUTY     2.0            0   Wednesday    False
# 3 2013-01-02          1   BEVERAGES  1091.0            0   Wednesday    False
# 4 2013-01-02          1       BOOKS     0.0            0   Wednesday    False
#
#    price
# 0  93.14
# 1  93.14
# 2  93.14
# 3  93.14
# 4  93.14

# %% [markdown]
# Adding Column is_holiday to trainClean

# %%
holidays = pd.read_csv("../Data/holidays_events.csv")
holidays["date"] = pd.to_datetime(holidays["date"])
holidaysOnly= holidays[holidays["type"] == "Holiday"]
trainClean = trainClean.merge(holidaysOnly, on="date")
print(holidays["locale"].value_counts())
print(trainClean.loc[23654])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-02c0dc8f9ec2> in <module>
# ----> 1 holidays = pd.read_csv("../Data/holidays_events.csv")
#       2 holidays["date"] = pd.to_datetime(holidays["date"])
#       3 holidaysOnly= holidays[holidays["type"] == "Holiday"]
#       4 trainClean = trainClean.merge(holidaysOnly, on="date")
#       5 print(holidays["locale"].value_counts())
#
# ...

# %%
holidays
